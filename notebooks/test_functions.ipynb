# %%
"""
Test Notebook for reading the hvz source .js file
"""
# Out:
# '\nTest Notebook for reading the hvz source .js file\n'

# %%
import os

# %%
def js_to_asci(filename):
    """
    convert the .js file to a .txt file, since its no code anyway
    """
    new_filename = filename[:-3] + '.txt'
    os.rename(filename, new_filename)

# %%
js_to_asci('../js_basefiles/hvz_peg_stm_test.js')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-c654aeb5050d> in <module>()
# ----> 1 js_to_asci('../js_basefiles/hvz_peg_stm_test.js')
#
# <ipython-input-6-b6119c04fe93> in js_to_asci(filename)
#       4     """
#       5     new_filename = filename[:-3] + '.txt'
# ----> 6     os.rename(filename, new_filename)
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: '../js_basefiles/hvz_peg_stm_test.js' -> '../js_basefiles/hvz_peg_stm_test.txt'
