# %%
"""
Open Weather Map API tool - Test Notebook
"""
# Out:
# '\nOpen Weather Map API tool - Test Notebook\n'

# %%
import os
import shutil
import urllib.request
import datetime

# %%
api_key = 'a6f114695799e59b0fb65a58d68eada6'
api_access = '&APPID=a6f114695799e59b0fb65a58d68eada6'
city_id = '6555933' #right now, city ID of WANNWEIL, because of Echaz.
api_url = 'http://api.openweathermap.org/data/2.5/weather?id=' + city_id + api_access

# %%
urllib.request.urlretrieve(api_url, 'test.json')
# Out:
# ('test.json', <http.client.HTTPMessage at 0x7fb6806d4160>)
