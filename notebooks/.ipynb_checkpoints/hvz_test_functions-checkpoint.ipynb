# %%
"""
Test Notebook for reading the hvz source .js file
"""
# Out:
# '\nTest Notebook for reading the hvz source .js file\n'

# %%
import os
import shutil

# %%
def js_to_asci(filename, destination):
    """
    copy the data file from the js_files directory to 
    the txt_files directory and convert it to a txt.
    """
    shutil.copyfile(filename, destination)

# %%
js_to_asci('../js_basefiles/js_files/hvz_peg_stm.js', '../js_basefiles/txt_files/hvz_peg_stm.txt')

# %%
def load_txt_datafile(filename):
    """
    Opens op the .txt datafile for post-processing
    """
    file_object = open(filename, 'r')
    
    return file_object

# %%
test = load_txt_datafile('../js_basefiles/txt_files/hvz_peg_stm.txt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-dfcd10174266> in <module>()
# ----> 1 test = load_txt_datafile('../js_basefiles/txt_files/hvz_peg_stm.txt')
#
# NameError: name 'load_txt_datafile' is not defined

# %%
file = open('../js_basefiles/js_files/hvz_peg_stm.js')

# %%
test = file.read().splitlines()

# %%
test[9].find('cm')
# Out:
# 45

# %%
testarr = test[9].split(',')

# %%
test[9]
# Out:
# " ['00212','Beutelsau','Untere Argen',1,'23','cm','19.09.2018 13:00','1.52','m³/s','19.09.2018 13:00',0,'BEUTELSAU',1,1,1,1,1,1,3561515,5285480,9.819767,47.705592,'0','265','553.59','m+NN','13.877','0',169,211,224,239,250,113.36,168.14,186.17,207.86,223.18,48,9.24,'',28,2.22,'',0,'','',1.35,'1981-2010','07.10.1997','','LUBW-HQ-Regionalisierung (Stand: 02.12.2013)','','LUBW-MQ-Regionalisierung (Stand: 14.01.2015)','','LUBW-MNQ-Regionalisierung (Stand: 14.01.2015)','','Tagesmittelwerte',0,1,'Regierungspräsidium Tübingen','https://rp.baden-wuerttemberg.de/','','','2.30!12.08.2002 |2.33!22.05.1999 |2.58!02.06.2013 '],"

# %%
testarr[5]
# Out:
# "'cm'"

# %%
test = json.loads(test_read)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-59-aee96169be94> in <module>()
# ----> 1 test = json.loads(test_read)
#
# ~/anaconda3/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~/anaconda3/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ~/anaconda3/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 2 column 3 (char 4)
